# %% [markdown]
# # Maths Lab
# The running notebook across all 17 modules. First: confirm the stack works.

# %%
import numpy, sympy, matplotlib, pandas, scipy
sympy.init_printing()
x = sympy.symbols('x')
sympy.factor(x**2 - 1)
